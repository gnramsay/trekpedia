# %% [markdown]
# # Trekpedia
#
#
# Writing a web-scraper to pull all `Star Trek(tm)` series data from Wikipedia.
#
# ## Stage 2 - get episode data
# Create separate json files containing episode data for each Series.
# For now we will keep all seasons in one file but may break this into individual ones depending on how much data we finally grab.

# %%
# common setup...
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import re

# don't truncate Pandas.DataFrame cell contents when displaying.
pd.set_option('display.max_colwidth', None)

# %%
# read in the data from stage 1 ...
df = pd.read_json('star_trek_series_info_stage_1.json', orient='index')
df
# Out:
#                   name  \
# 0  The Original Series
# 1  The Animated Series
# 2  The Next Generation
# 3      Deep Space Nine
# 4              Voyager
# 5           Enterprise
# 6            Discovery
# 7          Short Treks
# 8               Picard
# 9          Lower Decks
#
#                                                             url  season_count  \
# 0  https://en.wikipedia.org/wiki/Star_Trek:_The_Original_Series             3
# 1  https://en.wikipedia.org/wiki/Star_Trek:_The_Animated_Series             2
# 2  https://en.wikipedia.org/wiki/Star_Trek:_The_Next_Generation             7
# 3      https://en.wikipedia.org/wiki/Star_Trek:_Deep_Space_Nine             7
# 4              https://en.wikipedia.org/wiki/Star_Trek:_Voyager             7
# 5           https://en.wikipedia.org/wiki/Star_Trek:_Enterprise             4
# 6            https://en.wikipedia.org/wiki/Star_Trek:_Discovery             3
# 7          https://en.wikipedia.org/wiki/Star_Trek:_Short_Treks             2
# 8               https://en.wikipedia.org/wiki/Star_Trek:_Picard             1
# 9          https://en.wikipedia.org/wiki/Star_Trek:_Lower_Decks             1
#
#    episode_count  \
# 0             79
# 1             22
# 2            178
# 3            176
# 4            172
# 5             98
# 6             42
# 7             10
# 8             10
# 9             10
#
#                                                                     episodes_url  \
# 0  https://en.wikipedia.org/wiki/List_of_Star_Trek:_The_Original_Series_episodes
# 1                   https://en.wikipedia.org/wiki/Star_Trek:_The_Animated_Series
# 2  https://en.wikipedia.org/wiki/List_of_Star_Trek:_The_Next_Generation_episodes
# 3      https://en.wikipedia.org/wiki/List_of_Star_Trek:_Deep_Space_Nine_episodes
# 4              https://en.wikipedia.org/wiki/List_of_Star_Trek:_Voyager_episodes
# 5           https://en.wikipedia.org/wiki/List_of_Star_Trek:_Enterprise_episodes
# 6            https://en.wikipedia.org/wiki/List_of_Star_Trek:_Discovery_episodes
# 7                           https://en.wikipedia.org/wiki/Star_Trek:_Short_Treks
# 8                     https://en.wikipedia.org/wiki/Star_Trek:_Picard_(season_1)
# 9                https://en.wikipedia.org/wiki/Star_Trek:_Lower_Decks_(season_1)
#
#                                   dates  \
# 0      September 8, 1966 - June 3, 1969
# 1  September 8, 1973 - October 12, 1974
# 2     September 28, 1987 - May 23, 1994
# 3        January 4, 1993 - May 31, 1999
# 4       January 16, 1995 - May 23, 2001
# 5     September 26, 2001 - May 13, 2005
# 6          September 24, 2017 - present
# 7     October 4, 2018 - January 9, 2020
# 8            January 23, 2020 - present
# 9              August 6, 2020 - present
#
#                                                                                                                                                 logo
# 0                                  https://upload.wikimedia.org/wikipedia/commons/thumb/8/8a/Star_Trek_TOS_logo.svg/220px-Star_Trek_TOS_logo.svg.png
# 1                                  https://upload.wikimedia.org/wikipedia/commons/thumb/0/03/Star_Trek_TAS_logo.svg/220px-Star_Trek_TAS_logo.svg.png
# 2  https://upload.wikimedia.org/wikipedia/commons/thumb/1/15/Star_Trek_The_Next_Generation_Logo.svg/220px-Star_Trek_The_Next_Generation_Logo.svg.png
# 3                                  https://upload.wikimedia.org/wikipedia/commons/thumb/e/e7/Star_Trek_DS9_logo.svg/220px-Star_Trek_DS9_logo.svg.png
# 4                               https://upload.wikimedia.org/wikipedia/en/thumb/e/e2/Star_Trek_Voyager_Logo.svg/220px-Star_Trek_Voyager_Logo.svg.png
# 5                                  https://upload.wikimedia.org/wikipedia/commons/thumb/0/08/Star_Trek_ENT_logo.svg/220px-Star_Trek_ENT_logo.svg.png
# 6                      https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Star_Trek_Discovery_logo.svg/220px-Star_Trek_Discovery_logo.svg.png
# 7
# 8                            https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Star_Trek_Picard_logo.svg/220px-Star_Trek_Picard_logo.svg.png
# 9                                    https://upload.wikimedia.org/wikipedia/commons/thumb/5/57/Star_Trek_LD_logo.svg/220px-Star_Trek_LD_logo.svg.png

# %%
# set up a filename template...
FILE_TEMPLATE = 'star_trek_series_{}_{}_episodes.json'

for row in df.itertuples():
    # temp break out if not first series, just to lessen requests to wikipedia...
        
    print(f'Processing : {row.name}')
    filename = FILE_TEMPLATE.format(row.Index,row.name.replace(" ", "_").lower())
    print(f"  -> Using URL : {row.episodes_url}")
    print(f"  -> Storing episodes to '{filename}'")
    
#     if not row.Index == 0:
#         break
    
    # get and parse the webpage...
    result = requests.get(row.episodes_url)
    bs = BeautifulSoup(result.text, 'lxml')
    
    # wrap all this in a Try:Except block, there are a few series which need special handling...
    try:
        # find the episode summary table, will be the first table with the below classes in the document
        summary_rows = bs.find('table', attrs={'class': 'wikitable plainrowheaders'}).find('tbody').find_all('tr')[2:]
        for season in summary_rows:

                link = season.find('th')
                cells = season.find_all('td')
                season_number = link.text
                season_id = link.a['href']

                print(f'Season: {season_number}, (Table ID is "{season_id}")')
                print(f'  -> {cells[1].text} episodes, from {cells[2].text} to  {cells[3].text}')
    except AttributeError:
        print("Error, need to investigate!")

    print("\n-=<[ . ]>=-\n")
# Out:
# Processing : The Original Series
#   -> Using URL : https://en.wikipedia.org/wiki/List_of_Star_Trek:_The_Original_Series_episodes
#   -> Storing episodes to 'star_trek_series_0_the_original_series_episodes.json'
# Season: 1, (Table ID is "#Season_1_(1966–1967)")
#   -> 29 episodes, from September 8, 1966 (1966-09-08) to  April 13, 1967 (1967-04-13)
# Season: 2, (Table ID is "#Season_2_(1967–1968)")
#   -> 26 episodes, from September 15, 1967 (1967-09-15) to  March 29, 1968 (1968-03-29)
# Season: 3, (Table ID is "#Season_3_(1968–1969)")
#   -> 24 episodes, from September 20, 1968 (1968-09-20) to  June 3, 1969 (1969-06-03)
#
# -=<[ . ]>=-
#
# Processing : The Animated Series
#   -> Using URL : https://en.wikipedia.org/wiki/Star_Trek:_The_Animated_Series
#   -> Storing episodes to 'star_trek_series_1_the_animated_series_episodes.json'
# Season: 1, (Table ID is "#Season_1_(1973–74)")
#   -> 16 episodes, from September 8, 1973 (1973-09-08) to  January 12, 1974 (1974-01-12)
# Season: 2, (Table ID is "#Season_2_(1974)")
#   -> 6 episodes, from September 7, 1974 (1974-09-07) to  October 12, 1974 (1974-10-12)
#
# -=<[ . ]>=-
#
# Processing : The Next Generation
#   -> Using URL : https://en.wikipedia.org/wiki/List_of_Star_Trek:_The_Next_Generation_episodes
#   -> Storing episodes to 'star_trek_series_2_the_next_generation_episodes.json'
# Season: 1, (Table ID is "#Season_1_(1987–1988)")
#   -> 26 episodes, from September 28, 1987 (1987-09-28) to  May 16, 1988 (1988-05-16)
# Season: 2, (Table ID is "#Season_2_(1988–1989)")
#   -> 22 episodes, from November 21, 1988 (1988-11-21) to  July 17, 1989 (1989-07-17)
# Season: 3, (Table ID is "#Season_3_(1989–1990)")
#   -> 26 episodes, from September 25, 1989 (1989-09-25) to  June 18, 1990 (1990-06-18)
# Season: 4, (Table ID is "#Season_4_(1990–1991)")
#   -> 26 episodes, from September 24, 1990 (1990-09-24) to  June 17, 1991 (1991-06-17)
# Season: 5, (Table ID is "#Season_5_(1991–1992)")
#   -> 26 episodes, from September 23, 1991 (1991-09-23) to  June 15, 1992 (1992-06-15)
# Season: 6, (Table ID is "#Season_6_(1992–1993)")
#   -> 26 episodes, from September 21, 1992 (1992-09-21) to  June 21, 1993 (1993-06-21)
# Season: 7, (Table ID is "#Season_7_(1993–1994)")
#   -> 26 episodes, from September 20, 1993 (1993-09-20) to  May 23, 1994 (1994-05-23)
#
# -=<[ . ]>=-
#
# Processing : Deep Space Nine
#   -> Using URL : https://en.wikipedia.org/wiki/List_of_Star_Trek:_Deep_Space_Nine_episodes
#   -> Storing episodes to 'star_trek_series_3_deep_space_nine_episodes.json'
# Season: 1, (Table ID is "#Season_1_(1993)")
#   -> 20 episodes, from January 3, 1993 (1993-01-03) to  June 20, 1993 (1993-06-20)
# Season: 2, (Table ID is "#Season_2_(1993–94)")
#   -> 26 episodes, from September 26, 1993 (1993-09-26) to  June 12, 1994 (1994-06-12)
# Season: 3, (Table ID is "#Season_3_(1994–95)")
#   -> 26 episodes, from September 26, 1994 (1994-09-26) to  June 19, 1995 (1995-06-19)
# Season: 4, (Table ID is "#Season_4_(1995–96)")
#   -> 26 episodes, from October 2, 1995 (1995-10-02) to  June 17, 1996 (1996-06-17)
# Season: 5, (Table ID is "#Season_5_(1996–97)")
#   -> 26 episodes, from September 30, 1996 (1996-09-30) to  June 16, 1997 (1997-06-16)
# Season: 6, (Table ID is "#Season_6_(1997–98)")
#   -> 26 episodes, from September 29, 1997 (1997-09-29) to  June 17, 1998 (1998-06-17)
# Season: 7, (Table ID is "#Season_7_(1998–99)")
#   -> 26 episodes, from September 30, 1998 (1998-09-30) to  June 2, 1999 (1999-06-02)
#
# -=<[ . ]>=-
#
# Processing : Voyager
#   -> Using URL : https://en.wikipedia.org/wiki/List_of_Star_Trek:_Voyager_episodes
#   -> Storing episodes to 'star_trek_series_4_voyager_episodes.json'
# Season: 1, (Table ID is "#Season_1_(1995)")
#   -> 16 episodes, from January 16, 1995 (1995-01-16) to  May 22, 1995 (1995-05-22)
# Season: 2, (Table ID is "#Season_2_(1995–96)")
#   -> 26 episodes, from August 28, 1995 (1995-08-28) to  May 20, 1996 (1996-05-20)
# Season: 3, (Table ID is "#Season_3_(1996–97)")
#   -> 26 episodes, from September 4, 1996 (1996-09-04) to  May 21, 1997 (1997-05-21)
# Season: 4, (Table ID is "#Season_4_(1997–98)")
#   -> 26 episodes, from September 3, 1997 (1997-09-03) to  May 20, 1998 (1998-05-20)
# Season: 5, (Table ID is "#Season_5_(1998–99)")
#   -> 26 episodes, from October 14, 1998 (1998-10-14) to  May 26, 1999 (1999-05-26)
# Season: 6, (Table ID is "#Season_6_(1999–2000)")
#   -> 26 episodes, from September 22, 1999 (1999-09-22) to  May 24, 2000 (2000-05-24)
# Season: 7, (Table ID is "#Season_7_(2000–01)")
#   -> 26 episodes, from October 4, 2000 (2000-10-04) to  May 23, 2001 (2001-05-23)
#
# -=<[ . ]>=-
#
# Processing : Enterprise
#   -> Using URL : https://en.wikipedia.org/wiki/List_of_Star_Trek:_Enterprise_episodes
#   -> Storing episodes to 'star_trek_series_5_enterprise_episodes.json'
# Season: 1, (Table ID is "#Season_1_(2001–02)")
#   -> 26 episodes, from September 26, 2001 (2001-09-26) to  May 22, 2002 (2002-05-22)
# Season: 2, (Table ID is "#Season_2_(2002–03)")
#   -> 26 episodes, from September 18, 2002 (2002-09-18) to  May 21, 2003 (2003-05-21)
# Season: 3, (Table ID is "#Season_3_(2003–04)")
#   -> 24 episodes, from September 10, 2003 (2003-09-10) to  May 26, 2004 (2004-05-26)
# Season: 4, (Table ID is "#Season_4_(2004–05)")
#   -> 22 episodes, from October 8, 2004 (2004-10-08) to  May 13, 2005 (2005-05-13)
#
# -=<[ . ]>=-
#
# Processing : Discovery
#   -> Using URL : https://en.wikipedia.org/wiki/List_of_Star_Trek:_Discovery_episodes
#   -> Storing episodes to 'star_trek_series_6_discovery_episodes.json'
# Season: 1, (Table ID is "#Season_1_(2017–18)")
#   -> 15 episodes, from 9 to  September 24, 2017 (2017-09-24)
# Error, need to investigate!
#
# -=<[ . ]>=-
#
# Processing : Short Treks
#   -> Using URL : https://en.wikipedia.org/wiki/Star_Trek:_Short_Treks
#   -> Storing episodes to 'star_trek_series_7_short_treks_episodes.json'
# Season: 1, (Table ID is "#Season_1_(2018–19)")
#   -> 4 episodes, from October 4, 2018 (2018-10-04) to  January 3, 2019 (2019-01-03)
# Season: 2, (Table ID is "#Season_2_(2019–20)")
#   -> 6 episodes, from October 5, 2019 (2019-10-05) to  January 9, 2020 (2020-01-09)
#
# -=<[ . ]>=-
#
# Processing : Picard
#   -> Using URL : https://en.wikipedia.org/wiki/Star_Trek:_Picard_(season_1)
#   -> Storing episodes to 'star_trek_series_8_picard_episodes.json'
# Error, need to investigate!
#
# -=<[ . ]>=-
#
# Processing : Lower Decks
#   -> Using URL : https://en.wikipedia.org/wiki/Star_Trek:_Lower_Decks_(season_1)
#   -> Storing episodes to 'star_trek_series_9_lower_decks_episodes.json'
# Error, need to investigate!
#
# -=<[ . ]>=-
